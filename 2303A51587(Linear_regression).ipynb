# %% [markdown]
# <a href="https://colab.research.google.com/github/ramcharanw11/Applications_data_mining_/blob/main/2303A51569(Linear_regression).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_csv('/content/SLR_Salary_dataset.csv')
df
# Out:
#     Unnamed: 0  YearsExperience    Salary
# 0            0              1.2   39344.0
# 1            1              1.4   46206.0
# 2            2              1.6   37732.0
# 3            3              2.1   43526.0
# 4            4              2.3   39892.0
# 5            5              3.0   56643.0
# 6            6              3.1   60151.0
# 7            7              3.3   54446.0
# 8            8              3.3   64446.0
# 9            9              3.8   57190.0
# 10          10              4.0   63219.0
# 11          11              4.1   55795.0
# 12          12              4.1   56958.0
# 13          13              4.2   57082.0
# 14          14              4.6   61112.0
# 15          15              5.0   67939.0
# 16          16              5.2   66030.0
# 17          17              5.4   83089.0
# 18          18              6.0   81364.0
# 19          19              6.1   93941.0
# 20          20              6.9   91739.0
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0  YearsExperience         Salary
# count   30.000000        30.000000      30.000000
# mean    14.500000         5.413333   76004.000000
# std      8.803408         2.837888   27414.429785
# min      0.000000         1.200000   37732.000000
# 25%      7.250000         3.300000   56721.750000
# 50%     14.500000         4.800000   65238.000000
# 75%     21.750000         7.800000  100545.750000
# max     29.000000        10.600000  122392.000000

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
x=df['YearsExperience']
y=df['Salary']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, train_size = 0.7, test_size = 0.3, random_state = 100)

# %%
lr = LinearRegression()
lr.fit(x_train.values.reshape(-1,1), y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test.values.reshape(-1,1))

# %%
from sklearn.metrics import mean_squared_error, r2_score

mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

print(f"Mean Squared Error: {mse}")
print(f"R² Score: {r2}")
# Out:
# Mean Squared Error: 30310299.043402545
# R² Score: 0.9627668685473266

# %%
import matplotlib.pyplot as plt

plt.scatter(x_test, y_test, color='blue', label='Actual Data')
plt.plot(x_test, y_pred, color='red', linewidth=2, label='Predicted Line')
plt.xlabel("X values")
plt.ylabel("Y values")
plt.legend()
plt.show()

# %%
print(f"Intercept: {lr.intercept_}")
print(f"Coefficient: {lr.coef_[0]}")
# Out:
# Intercept: 24230.767402330348
# Coefficient: 9731.203838245377

# %%
new_x = [[10]]
new_pred = lr.predict(new_x)
print(f"Prediction for {new_x[0][0]}: {new_pred[0]}")
# Out:
# Prediction for 10: 121542.80578478411
